# %% [markdown]
# # A1: Automated Project: Planning, Estimation, and Allocation

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from utils import load_env
load_env()

import os
import yaml
from crewai import Agent, Task, Crew

# %% [markdown]
# ## Set OpenAI Model

# %%
os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/A1_agents.yaml',
    'tasks': 'config/A1_tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)

# %% [markdown]
# ## Crew's Inputs

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ## Kicking off the crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: aade969e-80e8-4f45-a4af-ae9eb3263ddb                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: The Ultimate Project Planner                                                                            │
# │                                                                                                                 │
# │  Task: Carefully analyze the project_requirements for the Website project and break them down into individual   │
# │  tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are      │
# │  accounted for:                                                                                                 │
# │                                                                                                                 │
# │  - Create a responsive design that works well on desktop and mobile devices                                     │
# │  - Implement a modern, visually appealing user interface with a clean look                                      │
# │  - Develop a user-friendly navigation system with intuitive menu structure                                      │
# │  - Include an "About Us" page highlighting the company's history and values                                     │
# │  - Design a "Services" page showcasing the business's offerings with descriptions                               │
# │  - Create a "Contact Us" page with a form and integrated map for communication                                  │
# │  - Implement a blog section for sharing industry news and company updates                                       │
# │  - Ensure fast loading times and optimize for search engines (SEO)                                              │
# │  - Integrate social media links and sharing capabilities                                                        │
# │  - Include a testimonials section to showcase customer feedback and build trust                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │  Team members:                                                                                                  │
# │                                                                                                                 │
# │  - John Doe (Project Manager)                                                                                   │
# │  - Jane Doe (Software Engineer)                                                                                 │
# │  - Bob Smith (Designer)                                                                                         │
# │  - Alice Johnson (QA Engineer)                                                                                  │
# │  - Tom Brown (QA Engineer)                                                                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: The Ultimate Project Planner                                                                            │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  ### Comprehensive Breakdown of Website Project Tasks                                                           │
# │                                                                                                                 │
# │  #### 1. **Create a Responsive Design**                                                                         │
# │     - **Description**: Develop a layout that adapts to different screen sizes and orientations for both         │
# │  desktop and mobile devices.                                                                                    │
# │     - **Scope**:                                                                                                │
# │       - Analyze current trends in responsive design.                                                            │
# │       - Establish CSS frameworks (like Bootstrap or Foundation).                                                │
# │       - Create wireframes for various devices.                                                                  │
# │     - **Team Member**: Bob Smith (Designer)                                                                     │
# │     - **Timeline**: 2 Weeks (Start: Week 1, End: Week 2)                                                        │
# │     - **Dependencies**: None                                                                                    │
# │     - **Deliverables**: Wireframes and responsive design prototypes.                                            │
# │                                                                                                                 │
# │  #### 2. **Implement a Modern User Interface**                                                                  │
# │     - **Description**: Design and implement a user interface that is sleek and visually appealing, ensuring     │
# │  aesthetic consistency.                                                                                         │
# │     - **Scope**:                                                                                                │
# │       - Choose color schemes and fonts.                                                                         │
# │       - Design UI elements such as buttons, icons, and forms.                                                   │
# │     - **Team Member**: Bob Smith (Designer), Jane Doe (Software Engineer)                                       │
# │     - **Timeline**: 3 Weeks (Start: Week 2, End: Week 4)                                                        │
# │     - **Dependencies**: Completion of responsive design                                                         │
# │     - **Deliverables**: UI design mockups and implemented components.                                           │
# │                                                                                                                 │
# │  #### 3. **Develop a User-Friendly Navigation System**                                                          │
# │     - **Description**: Create an intuitive navigation menu to help users easily find information.               │
# │     - **Scope**:                                                                                                │
# │       - Define the main menu structure and sub-items.                                                           │
# │       - Ensure mobile navigation is thumb-friendly.                                                             │
# │     - **Team Member**: Jane Doe (Software Engineer)                                                             │
# │     - **Timeline**: 1 Week (Start: Week 4, End: Week 4)                                                         │
# │     - **Dependencies**: Completion of UI design                                                                 │
# │     - **Deliverables**: Fully functional navigation system.                                                     │
# │                                                                                                                 │
# │  #### 4. **Create an "About Us" Page**                                                                          │
# │     - **Description**: Develop content highlighting the company’s history, mission, and values.                 │
# │     - **Scope**:                                                                                                │
# │       - Write copy for the page.                                                                                │
# │       - Design layout consistent with the UI.                                                                   │
# │     - **Team Member**: Bob Smith (Designer), Jane Doe (Software Engineer)                                       │
# │     - **Timeline**: 1 Week (Start: Week 5, End: Week 5)                                                         │
# │     - **Dependencies**: UI implementation                                                                       │
# │     - **Deliverables**: Live About Us page.                                                                     │
# │                                                                                                                 │
# │  #### 5. **Design a "Services" Page**                                                                           │
# │     - **Description**: Showcase the business’s offerings clearly with detailed descriptions.                    │
# │     - **Scope**:                                                                                                │
# │       - Write copy, create images/icons for services.                                                           │
# │       - Ensure alignments with the overall design.                                                              │
# │     - **Team Member**: Bob Smith (Designer), Jane Doe (Software Engineer)                                       │
# │     - **Timeline**: 1 Week (Start: Week 5, End: Week 6)                                                         │
# │     - **Dependencies**: Completion of About Us page                                                             │
# │     - **Deliverables**: Live Services page.                                                                     │
# │                                                                                                                 │
# │  #### 6. **Create a "Contact Us" Page**                                                                         │
# │     - **Description**: Integrate forms for inquiries and provide a map for physical location.                   │
# │     - **Scope**:                                                                                                │
# │       - Design the form for inputs (name, email, message).                                                      │
# │       - Integrate Google Maps for location display.                                                             │
# │     - **Team Member**: Jane Doe (Software Engineer), Bob Smith (Designer)                                       │
# │     - **Timeline**: 1 Week (Start: Week 6, End: Week 6)                                                         │
# │     - **Dependencies**: Completion of Services page                                                             │
# │     - **Deliverables**: Fully functional Contact Us page.                                                       │
# │                                                                                                                 │
# │  #### 7. **Implement a Blog Section**                                                                           │
# │     - **Description**: Allow for easy posting and management of articles related to industry news and updates.  │
# │     - **Scope**:                                                                                                │
# │       - Development of a CMS for blog posts.                                                                    │
# │       - Design an interface for users to view and comment.                                                      │
# │     - **Team Member**: Jane Doe (Software Engineer)                                                             │
# │     - **Timeline**: 2 Weeks (Start: Week 7, End: Week 8)                                                        │
# │     - **Dependencies**: Completion of Services and About Us pages                                               │
# │     - **Deliverables**: Live blog section.                                                                      │
# │                                                                                                                 │
# │  #### 8. **Ensure Fast Loading Times and SEO Optimization**                                                     │
# │     - **Description**: Optimize all site elements for fast loading and better SEO.                              │
# │     - **Scope**:                                                                                                │
# │       - Minify CSS/JS files, optimize images.                                                                   │
# │       - Implement best practices for SEO (meta tags, keywords, alt text).                                       │
# │     - **Team Members**: Jane Doe (Software Engineer), Alice Johnson (QA Engineer)                               │
# │     - **Timeline**: 2 Weeks (Start: Week 8, End: Week 9)                                                        │
# │     - **Dependencies**: Completion of the blog section                                                          │
# │     - **Deliverables**: Site audited for speed and SEO.                                                         │
# │                                                                                                                 │
# │  #### 9. **Integrate Social Media Links and Sharing Capabilities**                                              │
# │     - **Description**: Add buttons for sharing and following on social media.                                   │
# │     - **Scope**:                                                                                                │
# │       - Define social media platforms to include.                                                               │
# │       - Design and implement sharing features on blog posts.                                                    │
# │     - **Team Members**: Jane Doe (Software Engineer), Bob Smith (Designer)                                      │
# │     - **Timeline**: 1 Week (Start: Week 9, End: Week 9)                                                         │
# │     - **Dependencies**: Completion of the blog section                                                          │
# │     - **Deliverables**: Functional social media integration.                                                    │
# │                                                                                                                 │
# │  #### 10. **Include a Testimonials Section**                                                                    │
# │     - **Description**: Create a section to showcase positive customer feedback.                                 │
# │     - **Scope**:                                                                                                │
# │       - Design layout and collect testimonials.                                                                 │
# │       - Ensure it aligns with the overall website aesthetics.                                                   │
# │     - **Team Members**: Bob Smith (Designer), Jane Doe (Software Engineer)                                      │
# │     - **Timeline**: 1 Week (Start: Week 10, End: Week 10)                                                       │
# │     - **Dependencies**: Completion of Services and About Us pages                                               │
# │     - **Deliverables**: Live testimonials section.                                                              │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Gantt Chart                                                                                                │
# │                                                                                                                 │
# │  Below is a Gantt chart representing the timeline for completing each task over the planned 10 weeks.           │
# │                                                                                                                 │
# │  ```                                                                                                            │
# │  | Task                          | Week 1 | Week 2 | Week 3 | Week 4 | Week 5 | Week 6 | Week 7 | Week 8 |      │
# │  Week 9 | Week 10 |                                                                                             │
# │  |-------------------------------|--------|--------|--------|--------|--------|--------|--------|--------|----  │
# │  ----|---------|                                                                                                │
# │  | Create a Responsive Design    |   X    |   X    |        |        |        |        |        |        |      │
# │  |         |                                                                                                    │
# │  | Implement UI                  |        |   X    |   X    |        |        |        |        |        |      │
# │  |         |                                                                                                    │
# │  | Develop Navigation System      |        |        |        |   X    |        |        |        |        |     │
# │  |         |                                                                                                    │
# │  | Create "About Us" Page       |        |        |        |        |   X    |        |        |        |       │
# │  |         |                                                                                                    │
# │  | Design "Services" Page       |        |        |        |        |   X    |   X    |        |        |       │
# │  |         |                                                                                                    │
# │  | Create "Contact Us" Page     |        |        |        |        |        |   X    |        |        |       │
# │  |         |                                                                                                    │
# │  | Implement Blog Section        |        |        |        |        |        |        |   X    |   X    |      │
# │  |         |                                                                                                    │
# │  | Optimize for Load Time & SEO |        |        |        |        |        |        |        |   X    |   X   │
# │  |         |                                                                                                    │
# │  | Integrate Social Media        |        |        |        |        |        |        |        |        |   X  │
# │  |         |                                                                                                    │
# │  | Include Testimonials Section   |        |        |        |        |        |        |        |        |     │
# │  |   X     |                                                                                                    │
# │  ```                                                                                                            │
# │                                                                                                                 │
# │  ### Conclusion                                                                                                 │
# │  Each task is designed to ensure all project requirements are met methodically. The team members have clear     │
# │  roles, achievable timelines have been set, and all dependencies are accounted for to deliver a successful      │
# │  website for the small business within the stipulated timeframe.                                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 109b9adc-14c9-4c77-8a49-a83d5e56e19a                                                                     │
# │  Agent: The Ultimate Project Planner                                                                            │
# │                                                                                                                 │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Expert Estimation Analyst                                                                               │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  ### Detailed Estimation Report for Website Project                                                             │
# │                                                                                                                 │
# │  #### 1. **Create a Responsive Design**                                                                         │
# │  - **Estimated Time**: 2 Weeks                                                                                  │
# │  - **Resources Required**: 1 Designer (Bob Smith)                                                               │
# │  - **Effort**: 80 hours                                                                                         │
# │  - **Associated Risks**: Analysis of trends may be subject to time constraints. User feedback on wireframes     │
# │  may require adjustments.                                                                                       │
# │                                                                                                                 │
# │  #### 2. **Implement a Modern User Interface**                                                                  │
# │  - **Estimated Time**: 3 Weeks                                                                                  │
# │  - **Resources Required**: 1 Designer (Bob Smith), 1 Software Engineer (Jane Doe)                               │
# │  - **Effort**: 120 hours (80 hours for Bob, 40 hours for Jane)                                                  │
# │  - **Associated Risks**: Potential misalignment between design and development. Possible need for multiple      │
# │  iteration cycles.                                                                                              │
# │                                                                                                                 │
# │  #### 3. **Develop a User-Friendly Navigation System**                                                          │
# │  - **Estimated Time**: 1 Week                                                                                   │
# │  - **Resources Required**: 1 Software Engineer (Jane Doe)                                                       │
# │  - **Effort**: 40 hours                                                                                         │
# │  - **Associated Risks**: Misinterpretation of user needs could lead to a navigation system that does not meet   │
# │  expectations.                                                                                                  │
# │                                                                                                                 │
# │  #### 4. **Create an "About Us" Page**                                                                          │
# │  - **Estimated Time**: 1 Week                                                                                   │
# │  - **Resources Required**: 1 Designer (Bob Smith), 1 Software Engineer (Jane Doe)                               │
# │  - **Effort**: 40 hours (20 hours for Bob, 20 hours for Jane)                                                   │
# │  - **Associated Risks**: Content approval process may cause delays; changes may be requested late in the        │
# │  process.                                                                                                       │
# │                                                                                                                 │
# │  #### 5. **Design a "Services" Page**                                                                           │
# │  - **Estimated Time**: 1 Week                                                                                   │
# │  - **Resources Required**: 1 Designer (Bob Smith), 1 Software Engineer (Jane Doe)                               │
# │  - **Effort**: 40 hours (20 hours for Bob, 20 hours for Jane)                                                   │
# │  - **Associated Risks**: Difficulty in showcasing services adequately might require additional revisions.       │
# │                                                                                                                 │
# │  #### 6. **Create a "Contact Us" Page**                                                                         │
# │  - **Estimated Time**: 1 Week                                                                                   │
# │  - **Resources Required**: 1 Designer (Bob Smith), 1 Software Engineer (Jane Doe)                               │
# │  - **Effort**: 40 hours (20 hours for Bob, 20 hours for Jane)                                                   │
# │  - **Associated Risks**: Technical issues with form integration may arise, potentially extending the timeline.  │
# │                                                                                                                 │
# │  #### 7. **Implement a Blog Section**                                                                           │
# │  - **Estimated Time**: 2 Weeks                                                                                  │
# │  - **Resources Required**: 1 Software Engineer (Jane Doe)                                                       │
# │  - **Effort**: 80 hours                                                                                         │
# │  - **Associated Risks**: CMS complexity and integration challenges could lead to unforeseen delays.             │
# │                                                                                                                 │
# │  #### 8. **Ensure Fast Loading Times and SEO Optimization**                                                     │
# │  - **Estimated Time**: 2 Weeks                                                                                  │
# │  - **Resources Required**: 1 Software Engineer (Jane Doe), 1 QA Engineer (Alice Johnson)                        │
# │  - **Effort**: 80 hours (60 hours for Jane, 20 hours for Alice)                                                 │
# │  - **Associated Risks**: SEO practices may need adjustments based on updated algorithms leading to potential    │
# │  re-work.                                                                                                       │
# │                                                                                                                 │
# │  #### 9. **Integrate Social Media Links and Sharing Capabilities**                                              │
# │  - **Estimated Time**: 1 Week                                                                                   │
# │  - **Resources Required**: 1 Software Engineer (Jane Doe), 1 Designer (Bob Smith)                               │
# │  - **Effort**: 40 hours (20 hours for each role)                                                                │
# │  - **Associated Risks**: Decision-making on social platforms could be delayed by stakeholder consultations.     │
# │                                                                                                                 │
# │  #### 10. **Include a Testimonials Section**                                                                    │
# │  - **Estimated Time**: 1 Week                                                                                   │
# │  - **Resources Required**: 1 Designer (Bob Smith), 1 Software Engineer (Jane Doe)                               │
# │  - **Effort**: 40 hours (20 hours for Bob, 20 hours for Jane)                                                   │
# │  - **Associated Risks**: Sourcing genuine testimonials could prove time-consuming, affecting timelines.         │
# │                                                                                                                 │
# │  ### Summary of Risks and Uncertainties                                                                         │
# │  - **Overall Project Risk**: Time for stakeholder feedback and needed revisions could create bottlenecks.       │
# │  - **Resource Availability**: Dependence on a few key team members might strain progress if any encounter       │
# │  personal emergencies.                                                                                          │
# │  - **Technological Uncertainties**: Unforeseen technical challenges could arise during integration and          │
# │  optimization tasks, which may extend timelines.                                                                │
# │                                                                                                                 │
# │  ### Conclusion                                                                                                 │
# │  This detailed estimation report captures the resources, time, and effort anticipated for each task within the  │
# │  Website project while considering associated risks. Precise planning enables efficient allocation of           │
# │  resources to ensure project completion within budget and schedule. The efforts conveyed above aim to raise     │
# │  awareness of potential challenges, thereby facilitating proactive mitigation strategies throughout the         │
# │  project lifecycle.                                                                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 9a2fedd1-67c9-4c78-ad38-1c299682268a                                                                     │
# │  Agent: Expert Estimation Analyst                                                                               │
# │                                                                                                                 │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Resource Allocation Strategist                                                                          │
# │                                                                                                                 │
# │  Task: Strategically allocate tasks for the Website project to team members based on their skills,              │
# │  availability, and current workload. Ensure that each task is assigned to the most suitable team member and     │
# │  that the workload is evenly distributed.                                                                       │
# │                                                                                                                 │
# │  Team members:                                                                                                  │
# │                                                                                                                 │
# │  - John Doe (Project Manager)                                                                                   │
# │  - Jane Doe (Software Engineer)                                                                                 │
# │  - Bob Smith (Designer)                                                                                         │
# │  - Alice Johnson (QA Engineer)                                                                                  │
# │  - Tom Brown (QA Engineer)                                                                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Resource Allocation Strategist                                                                          │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  {                                                                                                              │
# │    "tasks": [                                                                                                   │
# │      {                                                                                                          │
# │        "task_name": "Create a Responsive Design",                                                               │
# │        "estimated_time_hours": 80,                                                                              │
# │        "required_resources": ["Bob Smith (Designer)"]                                                           │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Implement a Modern User Interface",                                                        │
# │        "estimated_time_hours": 120,                                                                             │
# │        "required_resources": ["Bob Smith (Designer)", "Jane Doe (Software Engineer)"]                           │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Develop a User-Friendly Navigation System",                                                │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Jane Doe (Software Engineer)"]                                                   │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Create an 'About Us' Page",                                                                │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Bob Smith (Designer)", "Jane Doe (Software Engineer)"]                           │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Design a 'Services' Page",                                                                 │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Bob Smith (Designer)", "Jane Doe (Software Engineer)"]                           │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Create a 'Contact Us' Page",                                                               │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Bob Smith (Designer)", "Jane Doe (Software Engineer)"]                           │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Implement a Blog Section",                                                                 │
# │        "estimated_time_hours": 80,                                                                              │
# │        "required_resources": ["Jane Doe (Software Engineer)"]                                                   │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Ensure Fast Loading Times and SEO Optimization",                                           │
# │        "estimated_time_hours": 80,                                                                              │
# │        "required_resources": ["Jane Doe (Software Engineer)", "Alice Johnson (QA Engineer)"]                    │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Integrate Social Media Links and Sharing Capabilities",                                    │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Bob Smith (Designer)", "Jane Doe (Software Engineer)"]                           │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Include a Testimonials Section",                                                           │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Bob Smith (Designer)", "Jane Doe (Software Engineer)"]                           │
# │      }                                                                                                          │
# │    ],                                                                                                           │
# │    "milestones": [                                                                                              │
# │      {                                                                                                          │
# │        "milestone_name": "Design Phase Completion",                                                             │
# │        "tasks": [                                                                                               │
# │          "Create a Responsive Design",                                                                          │
# │          "Implement a Modern User Interface",                                                                   │
# │          "Develop a User-Friendly Navigation System"                                                            │
# │        ]                                                                                                        │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "milestone_name": "Content Development Completion",                                                      │
# │        "tasks": [                                                                                               │
# │          "Create an 'About Us' Page",                                                                           │
# │          "Design a 'Services' Page",                                                                            │
# │          "Create a 'Contact Us' Page"                                                                           │
# │        ]                                                                                                        │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "milestone_name": "Development Phase Completion",                                                        │
# │        "tasks": [                                                                                               │
# │          "Implement a Blog Section",                                                                            │
# │          "Ensure Fast Loading Times and SEO Optimization",                                                      │
# │          "Integrate Social Media Links and Sharing Capabilities"                                                │
# │        ]                                                                                                        │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "milestone_name": "Final Project Completion",                                                            │
# │        "tasks": [                                                                                               │
# │          "Include a Testimonials Section"                                                                       │
# ...
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: aade969e-80e8-4f45-a4af-ae9eb3263ddb                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: {                                                                                                │
# │    "tasks": [                                                                                                   │
# │      {                                                                                                          │
# │        "task_name": "Create a Responsive Design",                                                               │
# │        "estimated_time_hours": 80,                                                                              │
# │        "required_resources": ["Bob Smith (Designer)"]                                                           │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Implement a Modern User Interface",                                                        │
# │        "estimated_time_hours": 120,                                                                             │
# │        "required_resources": ["Bob Smith (Designer)", "Jane Doe (Software Engineer)"]                           │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Develop a User-Friendly Navigation System",                                                │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Jane Doe (Software Engineer)"]                                                   │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Create an 'About Us' Page",                                                                │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Bob Smith (Designer)", "Jane Doe (Software Engineer)"]                           │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Design a 'Services' Page",                                                                 │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Bob Smith (Designer)", "Jane Doe (Software Engineer)"]                           │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Create a 'Contact Us' Page",                                                               │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Bob Smith (Designer)", "Jane Doe (Software Engineer)"]                           │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Implement a Blog Section",                                                                 │
# │        "estimated_time_hours": 80,                                                                              │
# │        "required_resources": ["Jane Doe (Software Engineer)"]                                                   │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Ensure Fast Loading Times and SEO Optimization",                                           │
# │        "estimated_time_hours": 80,                                                                              │
# │        "required_resources": ["Jane Doe (Software Engineer)", "Alice Johnson (QA Engineer)"]                    │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Integrate Social Media Links and Sharing Capabilities",                                    │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Bob Smith (Designer)", "Jane Doe (Software Engineer)"]                           │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Include a Testimonials Section",                                                           │
# │        "estimated_time_hours": 40,                                                                              │
# │        "required_resources": ["Bob Smith (Designer)", "Jane Doe (Software Engineer)"]                           │
# │      }                                                                                                          │
# │    ],                                                                                                           │
# │    "milestones": [                                                                                              │
# │      {                                                                                                          │
# │        "milestone_name": "Design Phase Completion",                                                             │
# │        "tasks": [                                                                                               │
# │          "Create a Responsive Design",                                                                          │
# │          "Implement a Modern User Interface",                                                                   │
# │          "Develop a User-Friendly Navigation System"                                                            │
# │        ]                                                                                                        │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "milestone_name": "Content Development Completion",                                                      │
# │        "tasks": [                                                                                               │
# │          "Create an 'About Us' Page",                                                                           │
# │          "Design a 'Services' Page",                                                                            │
# │          "Create a 'Contact Us' Page"                                                                           │
# │        ]                                                                                                        │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "milestone_name": "Development Phase Completion",                                                        │
# │        "tasks": [                                                                                               │
# │          "Implement a Blog Section",                                                                            │
# │          "Ensure Fast Loading Times and SEO Optimization",                                                      │
# │          "Integrate Social Media Links and Sharing Capabilities"                                                │
# │        ]                                                                                                        │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "milestone_name": "Final Project Completion",                                                            │
# │        "tasks": [                                                                                               │
# │          "Include a Testimonials Section"                                                                       │
# │        ]                                                                                                        │
# │      }                                                                                                          │
# │    ]                                                                                                            │
# │  }                                                                                                              │
# │                                                                                                                 │
# │  ### Summary of Allocation Decisions:                                                                           │
# │  1. **Creating a Responsive Design** is assigned to Bob Smith (Designer) due to his expertise in design and     │
# │  layout. This task requires a specialized focus on design that aligns with responsive principles.               │
# │                                                                                                                 │
# │  2. **Implementing a Modern User Interface** includes both Bob Smith and Jane Doe, ensuring that the UI is      │
# │  visually appealing and functional. Their combined skills will allow for a seamless transition from design to   │
# │  development.                                                                                                   │
# │                                                                                                                 │
# │  3. **Developing a User-Friendly Navigation System** is allocated solely to Jane Doe as a Software Engineer,    │
# │  utilizing her skills to create an effective and intuitive navigation structure.                                │
# │                                                                                                                 │
# │  4. **Creating Content for the ‘About Us,’ ‘Services,’ and ‘Contact Us’ Pages** involves both Bob and Jane,     │
# │  ensuring that both the design and technical aspects are taken into consideration during content creation.      │
# │                                                                                                                 │
# │  5. **Implementing a Blog Section** is dedicated to Jane Doe, capitalizing on her software engineering          │
# │  expertise to manage CMS operations effectively.                                                                │
# │                                                                                                                 │
# │  6. **Ensuring Fast Loading Times and SEO Optimization** is a critical task involving both Jane and Alice       │
# │  Johnson (QA Engineer) for a thorough evaluation of performance metrics and SEO best practices.                 │
# │                                                                                                                 │
# │  7. **Integrating Social Media Links and Adding a Testimonials Section** both involve Bob and Jane, ensuring    │
# │  the aesthetic and functional integration of the components aligning with the overall website design.           │
# │                                                                                                                 │
# │  This task allocation aims to utilize team members' strengths while maintaining a balanced workload, enhancing  │
# │  collaboration, and ensuring project success all within the planned timeline.                                   │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ## Usage Metrics and Costs

# %% [markdown]
# Let’s see how much it would cost each time if this crew runs at scale.

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.model_dump()])
df_usage_metrics
# Out:
# Total costs: $0.0014
#    total_tokens  prompt_tokens  cached_prompt_tokens  completion_tokens  \
# 0          9459           5898                     0               3561
#
#    successful_requests
# 0                    3

# %% [markdown]
# ## Result

# %%
result.pydantic.model_dump()
# Out:
# {'tasks': [{'task_name': 'Create a Responsive Design',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Bob Smith (Designer)']},
#   {'task_name': 'Implement a Modern User Interface',
#    'estimated_time_hours': 120.0,
#    'required_resources': ['Bob Smith (Designer)',
#     'Jane Doe (Software Engineer)']},
#   {'task_name': 'Develop a User-Friendly Navigation System',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': "Create an 'About Us' Page",
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith (Designer)',
#     'Jane Doe (Software Engineer)']},
#   {'task_name': "Design a 'Services' Page",
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith (Designer)',
#     'Jane Doe (Software Engineer)']},
#   {'task_name': "Create a 'Contact Us' Page",
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith (Designer)',
#     'Jane Doe (Software Engineer)']},
#   {'task_name': 'Implement a Blog Section',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Ensure Fast Loading Times and SEO Optimization',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Jane Doe (Software Engineer)',
#     'Alice Johnson (QA Engineer)']},
#   {'task_name': 'Integrate Social Media Links and Sharing Capabilities',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith (Designer)',
#     'Jane Doe (Software Engineer)']},
#   {'task_name': 'Include a Testimonials Section',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith (Designer)',
#     'Jane Doe (Software Engineer)']}],
#  'milestones': [{'milestone_name': 'Design Phase Completion',
#    'tasks': ['Create a Responsive Design',
#     'Implement a Modern User Interface',
#     'Develop a User-Friendly Navigation System']},
#   {'milestone_name': 'Content Development Completion',
#    'tasks': ["Create an 'About Us' Page",
#     "Design a 'Services' Page",
#     "Create a 'Contact Us' Page"]},
#   {'milestone_name': 'Development Phase Completion',
#    'tasks': ['Implement a Blog Section',
#     'Ensure Fast Loading Times and SEO Optimization',
#     'Integrate Social Media Links and Sharing Capabilities']},
#   {'milestone_name': 'Final Project Completion',
#    'tasks': ['Include a Testimonials Section']}]}

# %% [markdown]
# ## Inspect further

# %%
tasks = result.pydantic.model_dump()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_5c87e th {
#   font-size: 120%;
# }
# #T_5c87e  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_5c87e" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c87e_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_5c87e_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_5c87e_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c87e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5c87e_row0_col0" class="data row0 col0" >Create a Responsive Design</td>
#       <td id="T_5c87e_row0_col1" class="data row0 col1" >80.000000</td>
#       <td id="T_5c87e_row0_col2" class="data row0 col2" >['Bob Smith (Designer)']</td>
#     </tr>
#     <tr>
#       <th id="T_5c87e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5c87e_row1_col0" class="data row1 col0" >Implement a Modern User Interface</td>
#       <td id="T_5c87e_row1_col1" class="data row1 col1" >120.000000</td>
#       <td id="T_5c87e_row1_col2" class="data row1 col2" >['Bob Smith (Designer)', 'Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_5c87e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5c87e_row2_col0" class="data row2 col0" >Develop a User-Friendly Navigation System</td>
#       <td id="T_5c87e_row2_col1" class="data row2 col1" >40.000000</td>
#       <td id="T_5c87e_row2_col2" class="data row2 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_5c87e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5c87e_row3_col0" class="data row3 col0" >Create an 'About Us' Page</td>
#       <td id="T_5c87e_row3_col1" class="data row3 col1" >40.000000</td>
#       <td id="T_5c87e_row3_col2" class="data row3 col2" >['Bob Smith (Designer)', 'Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_5c87e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5c87e_row4_col0" class="data row4 col0" >Design a 'Services' Page</td>
#       <td id="T_5c87e_row4_col1" class="data row4 col1" >40.000000</td>
#       <td id="T_5c87e_row4_col2" class="data row4 col2" >['Bob Smith (Designer)', 'Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_5c87e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5c87e_row5_col0" class="data row5 col0" >Create a 'Contact Us' Page</td>
#       <td id="T_5c87e_row5_col1" class="data row5 col1" >40.000000</td>
#       <td id="T_5c87e_row5_col2" class="data row5 col2" >['Bob Smith (Designer)', 'Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_5c87e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5c87e_row6_col0" class="data row6 col0" >Implement a Blog Section</td>
#       <td id="T_5c87e_row6_col1" class="data row6 col1" >80.000000</td>
#       <td id="T_5c87e_row6_col2" class="data row6 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_5c87e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5c87e_row7_col0" class="data row7 col0" >Ensure Fast Loading Times and SEO Optimization</td>
#       <td id="T_5c87e_row7_col1" class="data row7 col1" >80.000000</td>
#       <td id="T_5c87e_row7_col2" class="data row7 col2" >['Jane Doe (Software Engineer)', 'Alice Johnson (QA Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_5c87e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5c87e_row8_col0" class="data row8 col0" >Integrate Social Media Links and Sharing Capabilities</td>
#       <td id="T_5c87e_row8_col1" class="data row8 col1" >40.000000</td>
#       <td id="T_5c87e_row8_col2" class="data row8 col2" >['Bob Smith (Designer)', 'Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_5c87e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5c87e_row9_col0" class="data row9 col0" >Include a Testimonials Section</td>
#       <td id="T_5c87e_row9_col1" class="data row9 col1" >40.000000</td>
#       <td id="T_5c87e_row9_col2" class="data row9 col2" >['Bob Smith (Designer)', 'Jane Doe (Software Engineer)']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Inspecting Milestones

# %%
milestones = result.pydantic.model_dump()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_e5665 th {
#   font-size: 120%;
# }
# #T_e5665  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_e5665" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e5665_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_e5665_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5665_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e5665_row0_col0" class="data row0 col0" >Design Phase Completion</td>
#       <td id="T_e5665_row0_col1" class="data row0 col1" >['Create a Responsive Design', 'Implement a Modern User Interface', 'Develop a User-Friendly Navigation System']</td>
#     </tr>
#     <tr>
#       <th id="T_e5665_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e5665_row1_col0" class="data row1 col0" >Content Development Completion</td>
#       <td id="T_e5665_row1_col1" class="data row1 col1" >["Create an 'About Us' Page", "Design a 'Services' Page", "Create a 'Contact Us' Page"]</td>
#     </tr>
#     <tr>
#       <th id="T_e5665_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e5665_row2_col0" class="data row2 col0" >Development Phase Completion</td>
#       <td id="T_e5665_row2_col1" class="data row2 col1" >['Implement a Blog Section', 'Ensure Fast Loading Times and SEO Optimization', 'Integrate Social Media Links and Sharing Capabilities']</td>
#     </tr>
#     <tr>
#       <th id="T_e5665_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e5665_row3_col0" class="data row3 col0" >Final Project Completion</td>
#       <td id="T_e5665_row3_col1" class="data row3 col1" >['Include a Testimonials Section']</td>
#     </tr>
#   </tbody>
# </table>
